# %% [markdown]
# # Software installation: Julia and Visual Studio Code
# ## Introduction to programming
# ![waves.gif](attachment:waves.gif)
# ## Why Julia?
# - Fast
# - Easy to learn
# - Dynamic
# - Reproducible
# - Composable
# - General
# - Open source
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Installing Julia
#
# Download and install [Julia](https://julialang.org/)
#
# ![image.png](attachment:image.png)
#
#
# After installing, make sure that you can run Julia.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Choose an IDE
# ¿VIM, Jupyter or Visual Studio Code?
#
# ![giphy.webp](attachment:giphy.webp)
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# https://code.visualstudio.com/

# %% [markdown]
# ## Using Packages
# **Pkg**
#
# **IJulia**
#
# **Test Julia Kernel**

# %%
a = 10 
b = 10
function test(a,b)
    return a + b
end
c = test(a,b)
# Out:
# 20
